# %% [markdown]
# ## Ejercicio
#
# Escribir un programa que pida al usuario una palabra y la muestre 10 veces por pantalla.

# %% [markdown]
# ## Solución

# %%
word = input("Introduce una palabra: ")
cant = int(input("Dime cuántas veces quieres repetir la palabra '{}': ".format(word)))
for i in range(cant):
    print(word)
# Out:
# Alf y sus amigos
# Alf y sus amigos
# Alf y sus amigos
# Alf y sus amigos
# Alf y sus amigos
